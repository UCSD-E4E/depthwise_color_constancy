# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
test = "living_room_0046b_out_1"
rgb = cv2.imread('data/nyu_data/data/nyu2_train/living_room_0046b_out/1.jpg').astype(np.float64)/255
depth = cv2.imread('data/nyu_data/data/nyu2_train/living_room_0046b_out/1.png').astype(np.float32)
depth = depth#/depth.max()
depth = depth.mean(axis=2)
depth.tofile(f"./data/realsense_tests/{test}-depth.bin")
rgb.tofile(f"./data/realsense_tests/{test}-color.bin")

# %%
plt.imshow(rgb)

# %%
a_c_new = np.fromfile(f"./data/realsense_tests/{test}-lim-99-500.bin")
a_c_new = a_c_new.reshape(rgb.shape)
plt.imshow()

# %%
# Out:
# array([[[0.480737  , 0.48074481, 0.48076518, ..., 0.61983153,
#          0.61992058, 0.61995651],
#         [0.48063859, 0.48064576, 0.4806647 , ..., 0.6197931 ,
#          0.61988326, 0.61991964],
#         [0.48039385, 0.48039927, 0.48041426, ..., 0.61969785,
#          0.61979079, 0.61982826],
#         ...,
#         [0.38247766, 0.38242129, 0.38228074, ..., 0.60917306,
#          0.61138756, 0.61226335],
#         [0.38255385, 0.38249804, 0.38235893, ..., 0.60707065,
#          0.60939463, 0.61031391],
#         [0.38258449, 0.38252891, 0.3823904 , ..., 0.60621911,
#          0.60858679, 0.60952357]],
#
#        [[0.47493821, 0.47494533, 0.47496402, ..., 0.60780759,
#          0.60787507, 0.60790239],
#         [0.47483642, 0.4748429 , 0.47486014, ..., 0.60776181,
#          0.6078305 , 0.60785832],
#         [0.47458323, 0.47458795, 0.47460121, ..., 0.6076482 ,
#          0.60771998, 0.60774903],
#         ...,
#         [0.38235661, 0.38230055, 0.38216079, ..., 0.60772162,
#          0.60996073, 0.61084628],
#         [0.38243219, 0.38237669, 0.38223837, ..., 0.60558677,
#          0.60793678, 0.60886637],
#         [0.38246259, 0.38240732, 0.38226959, ..., 0.6047221 ,
#          0.60711637, 0.60806368]],
#
#        [[0.47990887, 0.47991806, 0.47994192, ..., 0.6153763 ,
#          0.61542568, 0.61544575],
#         [0.4798097 , 0.47981825, 0.47984065, ..., 0.61533305,
#          0.61538363, 0.61540419],
#         [0.47956309, 0.47956988, 0.47958828, ..., 0.61522576,
#          0.61527938, 0.61530117],
#         ...,
#         [0.38374414, 0.38369157, 0.38356048, ..., 0.62559001,
#          0.62773852, 0.62858824],
#         [0.38381368, 0.38376162, 0.38363188, ..., 0.62353745,
#          0.62579245, 0.62668446],
#         [0.38384165, 0.38378981, 0.38366062, ..., 0.6227061 ,
#          0.62500361, 0.62591265]]], shape=(3, 480, 640))
