# %%
import numpy as np
import matplotlib.pyplot as plt
test_name = "03_07_2024_projector_on_toolbox"


depth = np.fromfile(f"data/realsense_tests/03_07_2024_projector_on_toolbox-depth.bin")#.astype(np.float32)
depth = depth.reshape((720, 460800//720 ))
plt.imshow(depth/depth.max())

# %%
depth.max()
# Out:
# np.float64(2.3598235209493736e+27)
